# %% [markdown]
# # Personalised News Aggregator Machine Learning Model
# ## Title of the project : Personalized News Aggregator and Sentiment Analyzer
# ### Project is for the final year of my university.
# This model is essentially the backbone of the website which will aggregate news articles from various sources based on user preferences and performs sentiment analysis to provide users with personalized news content.
# #### Importing the necessary libraries:

# %%
# The following libraries are for data representation, manipulation and for numerical calculations.
import numpy as np 
import pandas as pd 

# Deep Learning library used to build and train the Recurrent Neural Network(RNN).
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout

# To split the dataset into train and test sets and also to calculate the accuracy.
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv

# %% [markdown]
# ### Loading the dataset to a pandas dataframe.

# %%
df = pd.read_csv('/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv')

# %% [markdown]
# ### Preprocessing of the dataset.

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# Out:
# (50000, 2)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
sentences = df['review'].values # Saving the Reviews separately.
labels = df['sentiment'].apply(lambda x: 1 if x == 'positive' else 0).values # Converting the label into binary values by applying a lambda function.

# %% [markdown]
# #### Tokenization and Padding.

# %%
tokenizer = Tokenizer(num_words = 5000) # Initializing the tokenizer to only change the most frequent 5000 words into an integer value.
tokenizer.fit_on_texts(sentences) # Fitting the tokenizer on the reviews of the dataset.
sequences = tokenizer.texts_to_sequences(sentences) # Finally converting the text into a sequence of integers.

# %%
# Padding the sequences such that all of the sequences will have same length.
X = pad_sequences(sequences, maxlen = 210) 
y = np.array(labels)

# %% [markdown]
# ### Splitting the data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 21) # 80 - 20 split of the dataset.

# %% [markdown]
# ### Building the RNN.
#
# The simple RNN will have 64 layers and L2(Ridge) Regularization will be used to prevent overfitting for the model.

# %%
model = Sequential() # Initializing the layers.
model.add(Embedding(input_dim = 5000, output_dim = 128)) # Mapping the 5000 unique words into a dense 128 dimensional vector.
model.add(SimpleRNN(64, return_sequences = False, kernel_regularizer = regularizers.l2(0.01))) # Adding a 64 unit simple RNN to the initialized network.
model.add(Dropout(0.69)) # Drops 67% of neurons randomly during training to prevent overfitting.
model.add(Dense(32, activation = 'relu', kernel_regularizer = regularizers.l2(0.01))) # Adding a 32 unit layer with ReLu activation function.
model.add(Dropout(0.69))
model.add(Dense(1, activation = 'sigmoid')) # Output layer with only one unit and sigmoid activation function.

# %% [markdown]
# #### Compiling the model using Adam optimizer.

# %%
model.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the model.

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 3, restore_best_weights = True)

history = model.fit(X_train, y_train, 
                    epochs = 15, batch_size = 128, 
                    validation_data = (X_test, y_test),
                    callbacks = [early_stopping])
# Out:
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726149394.104127    3466 service.cc:145] XLA service 0x7cdd2000ab60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726149394.104183    3466 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   7/313 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.5164 - loss: 1.9843
# I0000 00:00:1726149398.514235    3466 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.5045 - loss: 1.8860 - val_accuracy: 0.5182 - val_loss: 1.5994
# Epoch 2/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.5072 - loss: 1.5320 - val_accuracy: 0.6368 - val_loss: 1.3119
# Epoch 3/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.6051 - loss: 1.2343 - val_accuracy: 0.7882 - val_loss: 0.9369
# Epoch 4/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.7594 - loss: 0.9593 - val_accuracy: 0.8196 - val_loss: 0.7643
# Epoch 5/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8370 - loss: 0.7581 - val_accuracy: 0.8333 - val_loss: 0.6704
# Epoch 6/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8607 - loss: 0.6433 - val_accuracy: 0.8457 - val_loss: 0.5718
# Epoch 7/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8706 - loss: 0.5693 - val_accuracy: 0.8513 - val_loss: 0.5219
# Epoch 8/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8876 - loss: 0.4921 - val_accuracy: 0.8595 - val_loss: 0.4701
# Epoch 9/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9014 - loss: 0.4381 - val_accuracy: 0.8721 - val_loss: 0.4286
# Epoch 10/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9074 - loss: 0.3974 - val_accuracy: 0.8694 - val_loss: 0.4158
# Epoch 11/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9159 - loss: 0.3622 - val_accuracy: 0.8695 - val_loss: 0.4066
# Epoch 12/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9188 - loss: 0.3440 - val_accuracy: 0.8712 - val_loss: 0.3858
# Epoch 13/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9244 - loss: 0.3197 - val_accuracy: 0.8750 - val_loss: 0.3753
# Epoch 14/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9293 - loss: 0.3072 - val_accuracy: 0.8686 - val_loss: 0.3975
# Epoch 15/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9322 - loss: 0.2894 - val_accuracy: 0.8724 - val_loss: 0.3752

# %% [markdown]
# ### Evaluating the model.

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8717 - loss: 0.3752
# Test Accuracy: 0.8724

# %% [markdown]
# #### Making Predictions.

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(f'Accuracy Score: {accuracy_score(y_test, y_pred):.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Accuracy Score: 0.8724

# %% [markdown]
# ### Loading the data.

# %%
import joblib

joblib.dump(model, 'model.pkl') # model.pkl is the RNN.
# Out:
# ['model.pkl']
